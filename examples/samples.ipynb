# %% [markdown]
# # Conditional WaveGAN
# ---

# %%
from IPython.display import display, Audio

# %% [markdown]
# ### Good examples

# %%
print("one")
display(Audio('./1.wav', rate=16000))
print("four")
display(Audio('./4.wav', rate=16000))
print("six")
display(Audio('./6.wav', rate=16000))
print("seven")
display(Audio('./7.wav', rate=16000))
print("eight")
display(Audio('./8.wav', rate=16000))
print("nine")
display(Audio('./9.wav', rate=16000))
# Out:
# one
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# four
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# six
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# seven
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# eight
# ...

# %% [markdown]
# ### Bad examples

# %%
print("noise")
display(Audio('./noise.wav', rate=16000))
print("incomplete")
display(Audio('./incomplete.wav', rate=16000))
print("random")
display(Audio('./random.wav', rate=16000))
# Out:
# noise
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# incomplete
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# random
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
